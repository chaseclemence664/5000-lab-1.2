# %% [raw]
# ---
# title: "All About Me"
# author: "Chase Clemence"
# format:
#     revealjs:
#         code-fold: true
# bibliography: ../reference.bib
# execute:
#     enabled: true
# ---

# %% [markdown]
# ## Background
# - Pittsburgh, PA
# - Mom, Dad, and Younger Brother
# - 4 Dogs
# ![My Pups](./images/puppers.jpg)
#
# ## Education
# - Greensburg Salem School District
# - United States Air Force Academy
# ![My Undergrad](./images/usafa.jpg)
#
# ## Hobbies
# - Lifting
# - Running
# - Swimming
# - Reading
# - Skydiving
#
# ## References
# 1. [@bolyen2019reproducible]
# 2. [@agarwal2014big]

# %% [markdown]
# ## Plot

# %%
## Here's a graph
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()
